# %%
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import os
import numpy as np
from skimage.transform import resize
#This program reads models from a folder (example: Those saved by Modelcheckpoint in tensorboard) and runs predictions on a
#folder of images.
imageheight=200
imagewidth=300
cutoff=0.6 #Above which is an echolcation and below is abnormal file
mfolder = "./weights/" #Folder with saved models in h5 format
ifolder = "../abcopy/a/" #Folder with images to test model with
foldercheck2 = False #Do you want to check the 2nd folder of images?
ifolder2 = "../abcopy/a/" #Folder with images to test model with
foldercheck3 = False #Do you want to check the 3rd folder of images?
ifolder3 = "../abcopy/a/" #Folder with images to test model with

cutoffdiff = int((1-cutoff)*10)
abcount = [0] * cutoffdiff 
mfilelist = [f for f in os.listdir(mfolder) if os.path.isfile(os.path.join(mfolder, f))] #Make list of model filenames
ifilelist = [f for f in os.listdir(ifolder) if os.path.isfile(os.path.join(ifolder, f))] #Make list of image filenames
if foldercheck2 == True:
    ifilelist2 = [f for f in os.listdir(ifolder2) if os.path.isfile(os.path.join(ifolder2, f))] #Make list of image filenames
if foldercheck3 == True:
    ifilelist3 = [f for f in os.listdir(ifolder3) if os.path.isfile(os.path.join(ifolder3, f))] #Make list of image filenames
print('Processing',len(ifilelist),'images in each model')
for mdl in range(len(mfilelist)):
    model = load_model(mfolder+mfilelist[mdl])
    #model.summary()
    abcount = [0] * cutoffdiff 
    for inum in range(len(ifilelist)):
        image = load_img(ifolder + ifilelist[inum], target_size=(imageheight,imagewidth))
        imageresize = image.resize((imagewidth, imageheight)) #Resize image for desired CNN model
        imagearray = img_to_array(imageresize) #Make image into an array
        imagearray = np.expand_dims(imagearray, 0) #Add 4th dimension to array for CNN -> will get error otherwise
        imagearray = imagearray.astype('float32')/255 #Convert array so that its predictions are readable
        prediction=model.predict(imagearray) #Run prediction on image-Returns list of float predictions
        for abdetermine in range(cutoffdiff):
            if prediction[0]<(cutoff+(abdetermine*0.1)):
                abcount[abdetermine]=abcount[abdetermine]+1
    print('Model',mdl+1,'of',len(mfilelist),':',mfilelist[mdl])
    for abprint in range(cutoffdiff):
        print('Abnormal count at cutoff',(cutoff+(abprint*0.1)),':'
              ,abcount[abprint],'at','{0:.2%}'.format(abcount[abprint]/len(ifilelist)),'% Echolocation count:',
             (len(ifilelist)-abcount[abprint]),'at','{0:.2%}'.format((len(ifilelist)-abcount[abprint])/len(ifilelist)))
    if foldercheck2 == True:
        print('Processing',len(ifilelist2),'images in each model')
        abcount = [0] * cutoffdiff
        for inum in range(len(ifilelist2)):
            image = load_img(ifolder2 + ifilelist2[inum], target_size=(imageheight,imagewidth))
            imageresize = image.resize((imagewidth, imageheight)) #Resize image for desired CNN model
            imagearray = img_to_array(imageresize) #Make image into an array
            imagearray = np.expand_dims(imagearray, 0) #Add 4th dimension to array for CNN -> will get error otherwise
            imagearray = imagearray.astype('float32')/255 #Convert array so that its predictions are readable
            prediction=model.predict(imagearray) #Run prediction on image-Returns list of float predictions
            for abdetermine in range(cutoffdiff):
                if prediction[0]<(cutoff+(abdetermine*0.1)):
                    abcount[abdetermine]=abcount[abdetermine]+1
        print('Folder 2 results:')
        for abprint in range(cutoffdiff):
            print('Abnormal count at cutoff',(cutoff+(abprint*0.1)),':'
                 ,abcount[abprint],'at','{0:.2%}'.format(abcount[abprint]/len(ifilelist2)),'% Echolocation count:',
                 (len(ifilelist2)-abcount[abprint]),'at','{0:.2%}'.format((len(ifilelist2)-abcount[abprint])/len(ifilelist2)))
    if foldercheck3 == True:
        print('Processing',len(ifilelist3),'images in each model')
        abcount = [0] * cutoffdiff
        for inum in range(len(ifilelist3)):
            image = load_img(ifolder3 + ifilelist3[inum], target_size=(imageheight,imagewidth))
            imageresize = image.resize((imagewidth, imageheight)) #Resize image for desired CNN model
            imagearray = img_to_array(imageresize) #Make image into an array
            imagearray = np.expand_dims(imagearray, 0) #Add 4th dimension to array for CNN -> will get error otherwise
            imagearray = imagearray.astype('float32')/255 #Convert array so that its predictions are readable
            prediction=model.predict(imagearray) #Run prediction on image-Returns list of float predictions
            for abdetermine in range(cutoffdiff):
                if prediction[0]<(cutoff+(abdetermine*0.1)):
                    abcount[abdetermine]=abcount[abdetermine]+1
        print('Folder 3 results:')
        for abprint in range(cutoffdiff):
            print('Abnormal count at cutoff',(cutoff+(abprint*0.1)),':'
                ,abcount[abprint],'at','{0:.2%}'.format(abcount[abprint]/len(ifilelist3)),'% Echolocation count:',
                (len(ifilelist3)-abcount[abprint]),'at','{0:.2%}'.format((len(ifilelist3)-abcount[abprint])/len(ifilelist3)))
    print('End of model',mfilelist[mdl],'predictions')
print('Finished')
# Out:
# ('Processing', 37, 'images in each model')
# ('Model', 1, 'of', 1, ':', 'CNN200x300ep30-Copy1.h5')
# ('Abnormal count at cutoff', 0.6, ':', 28, 'at', '0.00%', '% Echolocation count:', 9, 'at', '0.00%')
# ('Abnormal count at cutoff', 0.7, ':', 28, 'at', '0.00%', '% Echolocation count:', 9, 'at', '0.00%')
# ('Abnormal count at cutoff', 0.8, ':', 29, 'at', '0.00%', '% Echolocation count:', 8, 'at', '0.00%')
# ('Abnormal count at cutoff', 0.9, ':', 29, 'at', '0.00%', '% Echolocation count:', 8, 'at', '0.00%')
# ('End of model', 'CNN200x300ep30-Copy1.h5', 'predictions')
# Finished
